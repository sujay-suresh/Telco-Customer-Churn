# %%
# Telco Customer Churn Analysis
# This is a jupyter notebook that analyses the root causes for telco customer churn at a company, identifies and recommends potential solutions to remediate this issue. 

# 1. Business Problem ----
# Company: Telecom provider
# Problem: X% of customers are left the company in the previous quarter
# Cost: $X million in lost revenue
# Question: Why are they leaving? How do we stop it?
# Analysis: 
# 1. Who churns most (segments)
# 2. What predicts churn (behaviours)
# 3. what intervention works (A/B Test) 
# 4. ROI of retention campaigns


# 3. Exploratory Analysis
# 4. Cohort Analysis
# 5. A/B Test Simulation
# 6. Predictive Model
# 7. Recommendations

# %%
# 2. Setup ----

# Libraries
import pandas as pd
import numpy as np

# Settings
pd.set_option('display.max_columns', None)

# Load Data
df = pd.read_csv('telco_customer_churn.csv')
df.head()
df.describe()
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# 3. Data Cleaning ----

# Missing values

# Errroneous values
